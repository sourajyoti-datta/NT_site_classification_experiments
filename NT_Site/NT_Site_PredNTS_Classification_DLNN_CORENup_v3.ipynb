# %%
##################################################################################
##### Define all parameters for model tuning
##################################################################################

n_fold = 5
expName = "NT_Site_PredNTS_Classification_DLNN_CORENup_v3"
outPath = "Results"
foldName = "folds.pickle"

epochs = 50
batch_size = 64
shuffle = True
seed = None

input_data_folder = "Data"
training_data_file = "Training-datasets-PredNTS.txt"
independent_data_file = "independent dataset-PredNTS.txt"

# %%
import os 
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, confusion_matrix
from sklearn.metrics import roc_auc_score, matthews_corrcoef

import math

# %%
# print(tf.test.is_gpu_available(cuda_only=True))
# physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
##################################################################################
##### define all CUSTOM functions
##################################################################################

def one_hot_encode_nt(sequence, char_dict):
    
    seq_encoded = np.zeros((len(sequence),len(char_dict)))
    
    i = 0
    for single_character in sequence:
        if(single_character.upper() in char_dict.keys()):
            seq_encoded[i][char_dict[single_character.upper()]] = 1
            i = i+1
        else:
            raise ValueError('Incorrect character in NT sequence: '+sequence)
    return seq_encoded

# %%
##################################################################################
##### Build k-fold functions
##################################################################################

## Build the K-fold from dataset
def build_kfold(features, labels, k=10, shuffle=False, seed=None):
    
    skf = StratifiedKFold(n_splits=k, shuffle=shuffle, random_state=seed)
    kfoldList = []
    for train_index, test_index in skf.split(features, labels):
        X_train, X_test = features[train_index], features[test_index]
        y_train, y_test = labels[train_index], labels[test_index]
        kfoldList.append({
            "X_train": X_train,
            "X_test": X_test,
            "y_train":y_train,
            "y_test":y_test
        })
    return kfoldList

# %%
##################################################################################
##### define evaluator functions
##################################################################################

def pred2label(y_pred):
    y_pred = np.round(y_pred)
    return y_pred

# %%
##################################################################################
##### Function to customize the DLNN architecture with parameters
##################################################################################

def DLNN_CORENup(input_seq_shape = (41, 21),
                 conv_filters_per_layer = 10, kernel_length = [10,5], conv_strides = 1,
                 max_pool_width = 3, max_pool_stride = 3, ## 1st Maxpool layer parameters
                 rnn_decode_units = 25, ## LSTM layer parameters
                 dense_decode_units = 128, ## Dense layer parameters
                 prob = 0.5, learn_rate = 0.001, 
                 loss = 'binary_crossentropy', metrics = None):
    
    beta = 0.001
    
    ######################################################################################################
    ########  SEQUENCE input  ############################################################################
    ######################################################################################################
    
    input1 = tf.keras.layers.Input(shape=input_seq_shape)
    
    ######################################################################################################
    ########  CONV Path  ############################################################################
    ######################################################################################################

    ## Conv layers
    
    for i in range(len(kernel_length)):
        
        if i == 0:
            conv = tf.keras.layers.Conv1D(conv_filters_per_layer, kernel_length[i],
                                          strides = conv_strides, kernel_regularizer = tf.keras.regularizers.l2(beta)
                                        )(input1)
        else:
            conv = tf.keras.layers.Conv1D(conv_filters_per_layer, kernel_length[i], 
                                          strides = conv_strides, kernel_regularizer = tf.keras.regularizers.l2(beta)
                                         )(conv)
        
        conv = tf.keras.layers.Activation('relu')(conv)
        conv = tf.keras.layers.MaxPool1D(pool_size = max_pool_width, strides = max_pool_stride)(conv)

    conv = tf.keras.layers.Flatten()(conv)
    
    ## Conv Scorer
    
#     conv = tf.keras.layers.Dropout(prob)(conv)
    
    conv = tf.keras.layers.Dense(dense_decode_units, 
                                 kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                 activation = 'relu')(conv)
    
    conv = tf.keras.layers.Dropout(prob)(conv)
    
    conv = tf.keras.layers.Dense(1, 
                                 kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                 activation = 'sigmoid')(conv)
    
    ######################################################################################################
    ########  RNN Path  ############################################################################
    ######################################################################################################
    
    ## RNN

    rnn = tf.keras.layers.GRU(rnn_decode_units, return_sequences = True, 
                              kernel_regularizer = tf.keras.regularizers.l2(beta))(input1)
    
    rnn = tf.keras.layers.Flatten()(rnn)
    
    ## RNN scorer
    
#     rnn = tf.keras.layers.Dropout(prob)(rnn)
    
    rnn = tf.keras.layers.Dense(dense_decode_units, 
                                kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                activation = 'relu')(rnn)
    
    rnn = tf.keras.layers.Dropout(prob)(rnn)
    
    rnn = tf.keras.layers.Dense(1, 
                                kernel_regularizer = tf.keras.regularizers.l2(beta), 
                                activation = 'sigmoid')(rnn)
    
    ######################################################################################################
    ########  Classifier  ################################################################################
    ######################################################################################################
    
    y = tf.keras.layers.Concatenate()([conv, rnn])
    
    y = tf.keras.layers.Dense(1, 
                              kernel_regularizer = tf.keras.regularizers.l2(beta), 
                              activation = 'sigmoid')(y)

    ## Generate Model from input and output
    model = tf.keras.models.Model(inputs=input1, outputs=y)
    
    ## Compile model
    if(metrics != None):
        model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=learn_rate), loss = loss, metrics = metrics)
    else:
        model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=learn_rate), loss = loss)

    return model

# %%
DLNN_CORENup().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 41, 21)]     0           []
#
#  conv1d (Conv1D)                (None, 32, 10)       2110        ['input_1[0][0]']
#
#  activation (Activation)        (None, 32, 10)       0           ['conv1d[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 10, 10)       0           ['activation[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 6, 10)        510         ['max_pooling1d[0][0]']
#
#  activation_1 (Activation)      (None, 6, 10)        0           ['conv1d_1[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 2, 10)       0           ['activation_1[0][0]']
#
#  gru (GRU)                      (None, 41, 25)       3600        ['input_1[0][0]']
#
#  flatten (Flatten)              (None, 20)           0           ['max_pooling1d_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 1025)         0           ['gru[0][0]']
#
#  dense (Dense)                  (None, 128)          2688        ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 128)          131328      ['flatten_1[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 1)            129         ['dropout_1[0][0]']
#
#  concatenate (Concatenate)      (None, 2)            0           ['dense_1[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            3           ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 140,497
# Trainable params: 140,497
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
##################################################################################
##### read training file
##################################################################################
train_file_path = os.path.join(input_data_folder, training_data_file)
train_data = pd.read_csv(train_file_path, sep='\t', header=None)
train_data.columns = ['Sequence', 'name', 'id', 'flag', 'label_original', 'type']
train_data.head()

##################################################################################
##### Create dictionary of all characters in the NT sequence 
##################################################################################
all_char_set = set({})
for val in [set(val) for val in train_data['Sequence']]:
    all_char_set = all_char_set.union(val)
all_char_list = list(all_char_set)
all_char_list.sort()
all_char_dict = {}
for i in range(len(all_char_list)):
    all_char_dict[all_char_list[i]] = i
    
##################################################################################
##### Create OHE of sequence
##################################################################################
train_data['OHE_Sequence'] = pd.Series([one_hot_encode_nt(val, all_char_dict) 
                                        for val in train_data["Sequence"]])

##################################################################################
##### Fix the labels
##################################################################################
train_data['label'] = pd.Series([1 if val == 1 else 0 
                                 for val in train_data["label_original"]])

##################################################################################
##### Extract features and labels, create folds
##################################################################################

features = np.array(list(train_data['OHE_Sequence']))
labels = np.array(list(train_data['label']))
labels = labels.reshape((labels.shape[0], 1))

input_seq_shape = features[0].shape

folds = build_kfold(features, labels, k=n_fold, shuffle=shuffle, seed=seed)

## Write the k-fold dataset to file
foldPath = os.path.join(outPath, expName, "{}fold".format(n_fold))
if(not os.path.isdir(foldPath)):
    os.makedirs(foldPath)
pickle.dump(folds, open(os.path.join(foldPath, foldName), "wb"))

# %%
##################################################################################
##### For each input file, train model and generate different outputs in a structured folder
##################################################################################

## create the evaluation data structure for all iterations
evaluations = {
    "Fold" : [],
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

##################################################################################
##### Train/Test model on all folds, generate evaluations
##################################################################################

## Create and set directory to save model
modelPath = os.path.join(outPath, expName, "{}fold".format(n_fold), "models")
if(not os.path.isdir(modelPath)):
    os.makedirs(modelPath)

i = -1
for fold in folds:
    i += 1
    
    print("\nTrain/Test model on Fold #"+str(i)+".")
    
    model = DLNN_CORENup(input_seq_shape = input_seq_shape)
    
    ## Define the model callbacks for early stopping and saving the model. Then train model
    current_model_path = os.path.join(modelPath, "bestModel-fold{}.hdf5".format(i))
    modelCallbacks = [
        tf.keras.callbacks.ModelCheckpoint(current_model_path,
                                           monitor = 'val_loss', verbose = 1, save_best_only = True, 
                                           save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
    ]
    
    # adding random shuffling of the dataset for training purpose
    index_arr = np.arange(fold["X_train"].shape[0])
    index_arr = np.random.permutation(index_arr)
    
    model.fit(x = fold["X_train"][index_arr], y = fold["y_train"][index_arr], batch_size = batch_size, epochs = epochs, verbose = 1, 
              callbacks = modelCallbacks, validation_data = (fold["X_test"], fold["y_test"]))
    
    model = tf.keras.models.load_model(current_model_path)
    
    ##################################################################################
    ##### Prediction and metrics for TRAIN dataset
    ##################################################################################

    y_pred = model.predict(fold["X_train"])
    label_pred = pred2label(y_pred)
    
    # Compute precision, recall, sensitivity, specifity, mcc
    acc = accuracy_score(fold["y_train"], label_pred)
    prec = precision_score(fold["y_train"],label_pred)
    mcc = matthews_corrcoef(fold["y_train"], label_pred)

    conf = confusion_matrix(fold["y_train"], label_pred)
    tn, fp, fn, tp = conf.ravel()
    sens = tp/(tp+fn)
    spec = tn/(tn+fp)
    
    fpr, tpr, thresholds = roc_curve(fold["y_train"], y_pred)
    auc = roc_auc_score(fold["y_train"], y_pred)
    
    evaluations["Fold"].append(i)
    evaluations["Train_Test"].append("Train")
    evaluations["Accuracy"].append(acc)
    evaluations["Precision"].append(prec)
    evaluations["TPR"].append(tpr)
    evaluations["FPR"].append(fpr)
    evaluations["TPR_FPR_Thresholds"].append(thresholds)
    evaluations["AUC"].append(auc)
    evaluations["Sensitivity"].append(sens)
    evaluations["Specificity"].append(spec)
    evaluations["MCC"].append(mcc)
    
    ##################################################################################
    ##### Prediction and metrics for TEST dataset
    ##################################################################################

    y_pred = model.predict(fold["X_test"])
    label_pred = pred2label(y_pred)
    
    # Compute precision, recall, sensitivity, specifity, mcc
    acc = accuracy_score(fold["y_test"], label_pred)
    prec = precision_score(fold["y_test"],label_pred)
    mcc = matthews_corrcoef(fold["y_test"], label_pred)

    conf = confusion_matrix(fold["y_test"], label_pred)
    tn, fp, fn, tp = conf.ravel()
    sens = tp/(tp+fn)
    spec = tn/(tn+fp)
    
    fpr, tpr, thresholds = roc_curve(fold["y_test"], y_pred)
    auc = roc_auc_score(fold["y_test"], y_pred)
    
    evaluations["Fold"].append(i)
    evaluations["Train_Test"].append("Test")
    evaluations["Accuracy"].append(acc)
    evaluations["Precision"].append(prec)
    evaluations["TPR"].append(tpr)
    evaluations["FPR"].append(fpr)
    evaluations["TPR_FPR_Thresholds"].append(thresholds)
    evaluations["AUC"].append(auc)
    evaluations["Sensitivity"].append(sens)
    evaluations["Specificity"].append(spec)
    evaluations["MCC"].append(mcc)
# Out:
# Train/Test model on Fold #0.
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.9380
# Epoch 1: val_loss improved from inf to 0.86146, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 4s 29ms/step - loss: 0.9380 - val_loss: 0.8615
# Epoch 2/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8064
# Epoch 2: val_loss improved from 0.86146 to 0.75570, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7985 - val_loss: 0.7557
# Epoch 3/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7189
# Epoch 3: val_loss improved from 0.75570 to 0.69865, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7144 - val_loss: 0.6986
# Epoch 4/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6728
# Epoch 4: val_loss improved from 0.69865 to 0.66446, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6711 - val_loss: 0.6645
# Epoch 5/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6363
# Epoch 5: val_loss improved from 0.66446 to 0.65146, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6381 - val_loss: 0.6515
# Epoch 6/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6201
# Epoch 6: val_loss improved from 0.65146 to 0.62071, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6160 - val_loss: 0.6207
# Epoch 7/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5937
# Epoch 7: val_loss improved from 0.62071 to 0.59989, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5931 - val_loss: 0.5999
# Epoch 8/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5701
# Epoch 8: val_loss improved from 0.59989 to 0.59141, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5702 - val_loss: 0.5914
# Epoch 9/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5526
# Epoch 9: val_loss improved from 0.59141 to 0.58596, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5503 - val_loss: 0.5860
# Epoch 10/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5363
# Epoch 10: val_loss improved from 0.58596 to 0.58122, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5358 - val_loss: 0.5812
# Epoch 11/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5250
# Epoch 11: val_loss did not improve from 0.58122
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5249 - val_loss: 0.5865
# Epoch 12/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5184
# Epoch 12: val_loss did not improve from 0.58122
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5217 - val_loss: 0.5860
# Epoch 13/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5008
# Epoch 13: val_loss improved from 0.58122 to 0.57696, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold0.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.4984 - val_loss: 0.5770
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.4916
# Epoch 14: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4916 - val_loss: 0.5841
# Epoch 15/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4755
# Epoch 15: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 10ms/step - loss: 0.4771 - val_loss: 0.5883
# Epoch 16/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4598
# Epoch 16: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4587 - val_loss: 0.5864
# Epoch 17/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4496
# Epoch 17: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 10ms/step - loss: 0.4497 - val_loss: 0.5870
# Epoch 18/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4355
# Epoch 18: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4415 - val_loss: 0.5830
# Epoch 19/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4270
# Epoch 19: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4239 - val_loss: 0.5851
# Epoch 20/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4192
# Epoch 20: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4150 - val_loss: 0.5813
# Epoch 21/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3993
# Epoch 21: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4041 - val_loss: 0.5915
# Epoch 22/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.3904
# Epoch 22: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3940 - val_loss: 0.5845
# Epoch 23/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3803
# Epoch 23: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3858 - val_loss: 0.5922
# Epoch 24/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3775
# Epoch 24: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3772 - val_loss: 0.5884
# Epoch 25/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3688
# Epoch 25: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3692 - val_loss: 0.5918
# Epoch 26/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3598
# Epoch 26: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3628 - val_loss: 0.5929
# Epoch 27/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3553
# Epoch 27: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3573 - val_loss: 0.5945
# Epoch 28/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3485
# Epoch 28: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3494 - val_loss: 0.5984
# Epoch 29/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3469
# Epoch 29: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3457 - val_loss: 0.5999
# Epoch 30/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3369
# Epoch 30: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3402 - val_loss: 0.5994
# Epoch 31/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3362
# Epoch 31: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3372 - val_loss: 0.6009
# Epoch 32/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3355
# Epoch 32: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3342 - val_loss: 0.6063
# Epoch 33/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3308
# Epoch 33: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3296 - val_loss: 0.6099
# Epoch 34/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3257
# Epoch 34: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3267 - val_loss: 0.6033
# Epoch 35/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3169
# Epoch 35: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3203 - val_loss: 0.6079
# Epoch 36/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3159
# Epoch 36: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3181 - val_loss: 0.6086
# Epoch 37/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3153
# Epoch 37: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3154 - val_loss: 0.6084
# Epoch 38/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3073
# Epoch 38: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3106 - val_loss: 0.6098
# Epoch 39/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3082
# Epoch 39: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3092 - val_loss: 0.6134
# Epoch 40/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2995
# Epoch 40: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3061 - val_loss: 0.6155
# Epoch 41/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3004
# Epoch 41: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3034 - val_loss: 0.6113
# Epoch 42/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2951
# Epoch 42: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3022 - val_loss: 0.6036
# Epoch 43/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3009
# Epoch 43: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3009 - val_loss: 0.6179
# Epoch 44/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2984
# Epoch 44: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2983 - val_loss: 0.6187
# Epoch 45/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2944
# Epoch 45: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2939 - val_loss: 0.6161
# Epoch 46/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2903
# Epoch 46: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2908 - val_loss: 0.6164
# Epoch 47/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2860
# Epoch 47: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2870 - val_loss: 0.6130
# Epoch 48/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2830
# Epoch 48: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2860 - val_loss: 0.6277
# Epoch 49/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2837
# Epoch 49: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2850 - val_loss: 0.6180
# Epoch 50/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2837
# Epoch 50: val_loss did not improve from 0.57696
# 30/30 [==============================] - 0s 11ms/step - loss: 0.2814 - val_loss: 0.6258
#
# Train/Test model on Fold #1.
# Epoch 1/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.9497
# Epoch 1: val_loss improved from inf to 0.85557, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 2s 27ms/step - loss: 0.9391 - val_loss: 0.8556
# Epoch 2/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8076
# Epoch 2: val_loss improved from 0.85557 to 0.74586, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7979 - val_loss: 0.7459
# Epoch 3/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7146
# Epoch 3: val_loss improved from 0.74586 to 0.69136, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7130 - val_loss: 0.6914
# Epoch 4/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6761
# Epoch 4: val_loss improved from 0.69136 to 0.67270, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6710 - val_loss: 0.6727
# Epoch 5/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6428
# Epoch 5: val_loss improved from 0.67270 to 0.65396, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6432 - val_loss: 0.6540
# Epoch 6/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6299
# Epoch 6: val_loss improved from 0.65396 to 0.63953, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6271 - val_loss: 0.6395
# Epoch 7/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6145
# Epoch 7: val_loss did not improve from 0.63953
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6133 - val_loss: 0.6408
# Epoch 8/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6116
# Epoch 8: val_loss improved from 0.63953 to 0.62646, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6112 - val_loss: 0.6265
# Epoch 9/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6072
# Epoch 9: val_loss did not improve from 0.62646
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6071 - val_loss: 0.6331
# Epoch 10/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6050
# Epoch 10: val_loss improved from 0.62646 to 0.62170, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.6022 - val_loss: 0.6217
# Epoch 11/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5922
# Epoch 11: val_loss improved from 0.62170 to 0.62100, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5944 - val_loss: 0.6210
# Epoch 12/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5891
# Epoch 12: val_loss improved from 0.62100 to 0.61953, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5901 - val_loss: 0.6195
# Epoch 13/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5954
# Epoch 13: val_loss did not improve from 0.61953
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5900 - val_loss: 0.6202
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5842
# Epoch 14: val_loss improved from 0.61953 to 0.61406, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5842 - val_loss: 0.6141
# Epoch 15/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5820
# Epoch 15: val_loss did not improve from 0.61406
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5814 - val_loss: 0.6207
# Epoch 16/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5841
# Epoch 16: val_loss did not improve from 0.61406
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5789 - val_loss: 0.6160
# Epoch 17/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5739
# Epoch 17: val_loss did not improve from 0.61406
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5727 - val_loss: 0.6195
# Epoch 18/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5617
# Epoch 18: val_loss did not improve from 0.61406
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5688 - val_loss: 0.6170
# Epoch 19/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5662
# Epoch 19: val_loss did not improve from 0.61406
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5653 - val_loss: 0.6145
# Epoch 20/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5597
# Epoch 20: val_loss did not improve from 0.61406
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5608 - val_loss: 0.6154
# Epoch 21/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5487
# Epoch 21: val_loss improved from 0.61406 to 0.61399, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5535 - val_loss: 0.6140
# Epoch 22/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5469
# Epoch 22: val_loss did not improve from 0.61399
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5495 - val_loss: 0.6168
# Epoch 23/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5454
# Epoch 23: val_loss did not improve from 0.61399
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5446 - val_loss: 0.6169
# Epoch 24/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5352
# Epoch 24: val_loss did not improve from 0.61399
# 30/30 [==============================] - 0s 10ms/step - loss: 0.5354 - val_loss: 0.6173
# Epoch 25/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5284
# Epoch 25: val_loss improved from 0.61399 to 0.61354, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5257 - val_loss: 0.6135
# Epoch 26/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5108
# Epoch 26: val_loss did not improve from 0.61354
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5147 - val_loss: 0.6157
# Epoch 27/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5031
# Epoch 27: val_loss did not improve from 0.61354
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5114 - val_loss: 0.6148
# Epoch 28/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5037
# Epoch 28: val_loss did not improve from 0.61354
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5083 - val_loss: 0.6247
# Epoch 29/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4890
# Epoch 29: val_loss did not improve from 0.61354
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4940 - val_loss: 0.6166
# Epoch 30/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4824
# Epoch 30: val_loss improved from 0.61354 to 0.61324, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold1.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.4857 - val_loss: 0.6132
# Epoch 31/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4717
# Epoch 31: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4711 - val_loss: 0.6233
# Epoch 32/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4724
# Epoch 32: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4709 - val_loss: 0.6223
# Epoch 33/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4675
# Epoch 33: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 10ms/step - loss: 0.4670 - val_loss: 0.6270
# Epoch 34/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.4545
# Epoch 34: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 10ms/step - loss: 0.4585 - val_loss: 0.6355
# Epoch 35/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4435
# Epoch 35: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4438 - val_loss: 0.6297
# Epoch 36/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4366
# Epoch 36: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4357 - val_loss: 0.6199
# Epoch 37/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4297
# Epoch 37: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4302 - val_loss: 0.6198
# Epoch 38/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4277
# Epoch 38: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4292 - val_loss: 0.6215
# Epoch 39/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4139
# Epoch 39: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4167 - val_loss: 0.6228
# Epoch 40/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4136
# Epoch 40: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4140 - val_loss: 0.6293
# Epoch 41/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4006
# Epoch 41: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 10ms/step - loss: 0.4000 - val_loss: 0.6277
# Epoch 42/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3938
# Epoch 42: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3952 - val_loss: 0.6310
# Epoch 43/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3940
# Epoch 43: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3922 - val_loss: 0.6270
# Epoch 44/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3878
# Epoch 44: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3869 - val_loss: 0.6252
# Epoch 45/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3788
# Epoch 45: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3799 - val_loss: 0.6290
# Epoch 46/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3711
# Epoch 46: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3742 - val_loss: 0.6247
# Epoch 47/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3654
# Epoch 47: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3675 - val_loss: 0.6300
# Epoch 48/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3620
# Epoch 48: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3616 - val_loss: 0.6230
# Epoch 49/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3538
# Epoch 49: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3568 - val_loss: 0.6221
# Epoch 50/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.3574
# Epoch 50: val_loss did not improve from 0.61324
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3555 - val_loss: 0.6246
#
# Train/Test model on Fold #2.
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.9467
# Epoch 1: val_loss improved from inf to 0.85258, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 3s 30ms/step - loss: 0.9467 - val_loss: 0.8526
# Epoch 2/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8083
# Epoch 2: val_loss improved from 0.85258 to 0.74868, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.8007 - val_loss: 0.7487
# Epoch 3/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7234
# Epoch 3: val_loss improved from 0.74868 to 0.70016, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.7207 - val_loss: 0.7002
# Epoch 4/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6871
# Epoch 4: val_loss improved from 0.70016 to 0.67656, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.6851 - val_loss: 0.6766
# Epoch 5/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6624
# Epoch 5: val_loss improved from 0.67656 to 0.66218, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6594 - val_loss: 0.6622
# Epoch 6/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6424
# Epoch 6: val_loss improved from 0.66218 to 0.65283, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6437 - val_loss: 0.6528
# Epoch 7/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6320
# Epoch 7: val_loss improved from 0.65283 to 0.64736, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6320 - val_loss: 0.6474
# Epoch 8/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6236
# Epoch 8: val_loss improved from 0.64736 to 0.64518, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6265 - val_loss: 0.6452
# Epoch 9/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6237
# Epoch 9: val_loss improved from 0.64518 to 0.64083, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6226 - val_loss: 0.6408
# Epoch 10/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6206
# Epoch 10: val_loss did not improve from 0.64083
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6200 - val_loss: 0.6469
# Epoch 11/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6159
# Epoch 11: val_loss improved from 0.64083 to 0.63665, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6155 - val_loss: 0.6366
# Epoch 12/50
# 30/30 [==============================] - ETA: 0s - loss: 0.6100
# Epoch 12: val_loss improved from 0.63665 to 0.63505, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6100 - val_loss: 0.6350
# Epoch 13/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6047
# Epoch 13: val_loss improved from 0.63505 to 0.63462, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6066 - val_loss: 0.6346
# Epoch 14/50
# 30/30 [==============================] - ETA: 0s - loss: 0.6006
# Epoch 14: val_loss did not improve from 0.63462
# 30/30 [==============================] - 0s 11ms/step - loss: 0.6006 - val_loss: 0.6358
# Epoch 15/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5964
# Epoch 15: val_loss improved from 0.63462 to 0.63337, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5983 - val_loss: 0.6334
# Epoch 16/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5957
# Epoch 16: val_loss improved from 0.63337 to 0.63036, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5970 - val_loss: 0.6304
# Epoch 17/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5903
# Epoch 17: val_loss improved from 0.63036 to 0.62924, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5939 - val_loss: 0.6292
# Epoch 18/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5909
# Epoch 18: val_loss did not improve from 0.62924
# 30/30 [==============================] - 0s 10ms/step - loss: 0.5953 - val_loss: 0.6315
# Epoch 19/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5856
# Epoch 19: val_loss improved from 0.62924 to 0.62781, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5877 - val_loss: 0.6278
# Epoch 20/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5823
# Epoch 20: val_loss improved from 0.62781 to 0.62555, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5829 - val_loss: 0.6255
# Epoch 21/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5839
# Epoch 21: val_loss did not improve from 0.62555
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5825 - val_loss: 0.6283
# Epoch 22/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5760
# Epoch 22: val_loss improved from 0.62555 to 0.62380, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5775 - val_loss: 0.6238
# Epoch 23/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5727
# Epoch 23: val_loss did not improve from 0.62380
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5752 - val_loss: 0.6300
# Epoch 24/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5716
# Epoch 24: val_loss did not improve from 0.62380
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5716 - val_loss: 0.6241
# Epoch 25/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5731
# Epoch 25: val_loss improved from 0.62380 to 0.62349, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5713 - val_loss: 0.6235
# Epoch 26/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5667
# Epoch 26: val_loss did not improve from 0.62349
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5663 - val_loss: 0.6254
# Epoch 27/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5629
# Epoch 27: val_loss improved from 0.62349 to 0.62298, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5629 - val_loss: 0.6230
# Epoch 28/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5586
# Epoch 28: val_loss did not improve from 0.62298
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5593 - val_loss: 0.6244
# Epoch 29/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5583
# Epoch 29: val_loss improved from 0.62298 to 0.62137, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5599 - val_loss: 0.6214
# Epoch 30/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5542
# Epoch 30: val_loss did not improve from 0.62137
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5565 - val_loss: 0.6227
# Epoch 31/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5536
# Epoch 31: val_loss did not improve from 0.62137
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5584 - val_loss: 0.6219
# Epoch 32/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5512
# Epoch 32: val_loss did not improve from 0.62137
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5479 - val_loss: 0.6229
# Epoch 33/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5385
# Epoch 33: val_loss did not improve from 0.62137
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5460 - val_loss: 0.6215
# Epoch 34/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5460
# Epoch 34: val_loss improved from 0.62137 to 0.62088, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold2.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5433 - val_loss: 0.6209
# Epoch 35/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5382
# Epoch 35: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5421 - val_loss: 0.6271
# Epoch 36/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5400
# Epoch 36: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5414 - val_loss: 0.6256
# Epoch 37/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5391
# Epoch 37: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5389 - val_loss: 0.6221
# Epoch 38/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5263
# Epoch 38: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 10ms/step - loss: 0.5287 - val_loss: 0.6315
# Epoch 39/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5257
# Epoch 39: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5265 - val_loss: 0.6414
# Epoch 40/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5373
# Epoch 40: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5370 - val_loss: 0.6292
# Epoch 41/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5207
# Epoch 41: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5231 - val_loss: 0.6227
# Epoch 42/50
# 30/30 [==============================] - ETA: 0s - loss: 0.5216
# Epoch 42: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5216 - val_loss: 0.6221
# Epoch 43/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5143
# Epoch 43: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5207 - val_loss: 0.6319
# Epoch 44/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5206
# Epoch 44: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5206 - val_loss: 0.6250
# Epoch 45/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5173
# Epoch 45: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5134 - val_loss: 0.6247
# Epoch 46/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5075
# Epoch 46: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5090 - val_loss: 0.6284
# Epoch 47/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5026
# Epoch 47: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5038 - val_loss: 0.6283
# Epoch 48/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4990
# Epoch 48: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4991 - val_loss: 0.6285
# Epoch 49/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4981
# Epoch 49: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4953 - val_loss: 0.6402
# Epoch 50/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5069
# Epoch 50: val_loss did not improve from 0.62088
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5011 - val_loss: 0.6364
#
# Train/Test model on Fold #3.
# Epoch 1/50
# 27/30 [==========================>...] - ETA: 0s - loss: 0.9392
# Epoch 1: val_loss improved from inf to 0.85151, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 2s 27ms/step - loss: 0.9320 - val_loss: 0.8515
# Epoch 2/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8035
# Epoch 2: val_loss improved from 0.85151 to 0.75317, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 14ms/step - loss: 0.7966 - val_loss: 0.7532
# Epoch 3/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7247
# Epoch 3: val_loss improved from 0.75317 to 0.70050, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7197 - val_loss: 0.7005
# Epoch 4/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.6775
# Epoch 4: val_loss improved from 0.70050 to 0.66469, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.6763 - val_loss: 0.6647
# Epoch 5/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6503
# Epoch 5: val_loss improved from 0.66469 to 0.63899, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6478 - val_loss: 0.6390
# Epoch 6/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6268
# Epoch 6: val_loss improved from 0.63899 to 0.61551, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.6217 - val_loss: 0.6155
# Epoch 7/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6014
# Epoch 7: val_loss improved from 0.61551 to 0.59740, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5963 - val_loss: 0.5974
# Epoch 8/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5733
# Epoch 8: val_loss did not improve from 0.59740
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5818 - val_loss: 0.5976
# Epoch 9/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5762
# Epoch 9: val_loss improved from 0.59740 to 0.58552, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5760 - val_loss: 0.5855
# Epoch 10/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5713
# Epoch 10: val_loss improved from 0.58552 to 0.58195, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5633 - val_loss: 0.5819
# Epoch 11/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5532
# Epoch 11: val_loss did not improve from 0.58195
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5487 - val_loss: 0.5842
# Epoch 12/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5380
# Epoch 12: val_loss improved from 0.58195 to 0.58040, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5405 - val_loss: 0.5804
# Epoch 13/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5239
# Epoch 13: val_loss did not improve from 0.58040
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5277 - val_loss: 0.5849
# Epoch 14/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5134
# Epoch 14: val_loss did not improve from 0.58040
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5203 - val_loss: 0.5815
# Epoch 15/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5167
# Epoch 15: val_loss improved from 0.58040 to 0.56646, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5163 - val_loss: 0.5665
# Epoch 16/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4951
# Epoch 16: val_loss improved from 0.56646 to 0.56336, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4977 - val_loss: 0.5634
# Epoch 17/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4933
# Epoch 17: val_loss did not improve from 0.56336
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4905 - val_loss: 0.5642
# Epoch 18/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4769
# Epoch 18: val_loss improved from 0.56336 to 0.55710, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold3.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4765 - val_loss: 0.5571
# Epoch 19/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4660
# Epoch 19: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 10ms/step - loss: 0.4691 - val_loss: 0.5608
# Epoch 20/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4634
# Epoch 20: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4608 - val_loss: 0.5587
# Epoch 21/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4524
# Epoch 21: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4550 - val_loss: 0.5639
# Epoch 22/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4441
# Epoch 22: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4451 - val_loss: 0.5627
# Epoch 23/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4405
# Epoch 23: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4345 - val_loss: 0.5625
# Epoch 24/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4289
# Epoch 24: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4287 - val_loss: 0.5641
# Epoch 25/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4240
# Epoch 25: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4230 - val_loss: 0.5621
# Epoch 26/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4163
# Epoch 26: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4221 - val_loss: 0.5690
# Epoch 27/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4149
# Epoch 27: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4154 - val_loss: 0.5649
# Epoch 28/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.4063
# Epoch 28: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4060 - val_loss: 0.5636
# Epoch 29/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4019
# Epoch 29: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4032 - val_loss: 0.5625
# Epoch 30/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3941
# Epoch 30: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3934 - val_loss: 0.5654
# Epoch 31/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3863
# Epoch 31: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3872 - val_loss: 0.5652
# Epoch 32/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3839
# Epoch 32: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3835 - val_loss: 0.5639
# Epoch 33/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3767
# Epoch 33: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3777 - val_loss: 0.5701
# Epoch 34/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3761
# Epoch 34: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3762 - val_loss: 0.5670
# Epoch 35/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3742
# Epoch 35: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3712 - val_loss: 0.5648
# Epoch 36/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3714
# Epoch 36: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3727 - val_loss: 0.5770
# Epoch 37/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3649
# Epoch 37: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3640 - val_loss: 0.5681
# Epoch 38/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3628
# Epoch 38: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3601 - val_loss: 0.5647
# Epoch 39/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3564
# Epoch 39: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3572 - val_loss: 0.5698
# Epoch 40/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3561
# Epoch 40: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3552 - val_loss: 0.5690
# Epoch 41/50
# 30/30 [==============================] - ETA: 0s - loss: 0.3526
# Epoch 41: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3526 - val_loss: 0.5640
# Epoch 42/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.3478
# Epoch 42: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3465 - val_loss: 0.5686
# Epoch 43/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3383
# Epoch 43: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3429 - val_loss: 0.5672
# Epoch 44/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3415
# Epoch 44: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3410 - val_loss: 0.5663
# Epoch 45/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3298
# Epoch 45: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3352 - val_loss: 0.5848
# Epoch 46/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3378
# Epoch 46: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3367 - val_loss: 0.5661
# Epoch 47/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3321
# Epoch 47: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3316 - val_loss: 0.5654
# Epoch 48/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3243
# Epoch 48: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3264 - val_loss: 0.5674
# Epoch 49/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3310
# Epoch 49: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3250 - val_loss: 0.5655
# Epoch 50/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3199
# Epoch 50: val_loss did not improve from 0.55710
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3211 - val_loss: 0.5665
#
# Train/Test model on Fold #4.
# Epoch 1/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.9412
# Epoch 1: val_loss improved from inf to 0.84994, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 3s 27ms/step - loss: 0.9286 - val_loss: 0.8499
# Epoch 2/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.8012
# Epoch 2: val_loss improved from 0.84994 to 0.74505, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7922 - val_loss: 0.7451
# Epoch 3/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.7142
# Epoch 3: val_loss improved from 0.74505 to 0.68795, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.7115 - val_loss: 0.6880
# Epoch 4/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6647
# Epoch 4: val_loss improved from 0.68795 to 0.64755, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6616 - val_loss: 0.6476
# Epoch 5/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6269
# Epoch 5: val_loss improved from 0.64755 to 0.61939, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.6260 - val_loss: 0.6194
# Epoch 6/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.6040
# Epoch 6: val_loss improved from 0.61939 to 0.60561, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.6026 - val_loss: 0.6056
# Epoch 7/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5855
# Epoch 7: val_loss improved from 0.60561 to 0.60192, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5896 - val_loss: 0.6019
# Epoch 8/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.5807
# Epoch 8: val_loss improved from 0.60192 to 0.59258, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5794 - val_loss: 0.5926
# Epoch 9/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5711
# Epoch 9: val_loss improved from 0.59258 to 0.58926, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5692 - val_loss: 0.5893
# Epoch 10/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5639
# Epoch 10: val_loss improved from 0.58926 to 0.58358, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5608 - val_loss: 0.5836
# Epoch 11/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5554
# Epoch 11: val_loss improved from 0.58358 to 0.57737, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5499 - val_loss: 0.5774
# Epoch 12/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5492
# Epoch 12: val_loss improved from 0.57737 to 0.57483, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5465 - val_loss: 0.5748
# Epoch 13/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5360
# Epoch 13: val_loss did not improve from 0.57483
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5403 - val_loss: 0.5797
# Epoch 14/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5255
# Epoch 14: val_loss improved from 0.57483 to 0.57294, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5270 - val_loss: 0.5729
# Epoch 15/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5101
# Epoch 15: val_loss did not improve from 0.57294
# 30/30 [==============================] - 0s 11ms/step - loss: 0.5148 - val_loss: 0.5849
# Epoch 16/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.5113
# Epoch 16: val_loss improved from 0.57294 to 0.57002, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.5100 - val_loss: 0.5700
# Epoch 17/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4966
# Epoch 17: val_loss improved from 0.57002 to 0.56931, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4947 - val_loss: 0.5693
# Epoch 18/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4783
# Epoch 18: val_loss improved from 0.56931 to 0.56689, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4848 - val_loss: 0.5669
# Epoch 19/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4839
# Epoch 19: val_loss did not improve from 0.56689
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4847 - val_loss: 0.5705
# Epoch 20/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4664
# Epoch 20: val_loss improved from 0.56689 to 0.56558, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4654 - val_loss: 0.5656
# Epoch 21/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4595
# Epoch 21: val_loss improved from 0.56558 to 0.56293, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4590 - val_loss: 0.5629
# Epoch 22/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4509
# Epoch 22: val_loss improved from 0.56293 to 0.56028, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4511 - val_loss: 0.5603
# Epoch 23/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4501
# Epoch 23: val_loss improved from 0.56028 to 0.55807, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.4471 - val_loss: 0.5581
# Epoch 24/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4195
# Epoch 24: val_loss did not improve from 0.55807
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4312 - val_loss: 0.5722
# Epoch 25/50
# 30/30 [==============================] - ETA: 0s - loss: 0.4251
# Epoch 25: val_loss did not improve from 0.55807
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4251 - val_loss: 0.5689
# Epoch 26/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4164
# Epoch 26: val_loss did not improve from 0.55807
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4169 - val_loss: 0.5611
# Epoch 27/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4041
# Epoch 27: val_loss did not improve from 0.55807
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4060 - val_loss: 0.5584
# Epoch 28/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.4009
# Epoch 28: val_loss did not improve from 0.55807
# 30/30 [==============================] - 0s 11ms/step - loss: 0.4021 - val_loss: 0.5604
# Epoch 29/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3966
# Epoch 29: val_loss improved from 0.55807 to 0.55652, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3964 - val_loss: 0.5565
# Epoch 30/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3828
# Epoch 30: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3873 - val_loss: 0.5576
# Epoch 31/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3801
# Epoch 31: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3808 - val_loss: 0.5594
# Epoch 32/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3727
# Epoch 32: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3733 - val_loss: 0.5602
# Epoch 33/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.3707
# Epoch 33: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3715 - val_loss: 0.5636
# Epoch 34/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3618
# Epoch 34: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3646 - val_loss: 0.5662
# Epoch 35/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3569
# Epoch 35: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3587 - val_loss: 0.5582
# Epoch 36/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3618
# Epoch 36: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3574 - val_loss: 0.5581
# Epoch 37/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3428
# Epoch 37: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3461 - val_loss: 0.5646
# Epoch 38/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.3478
# Epoch 38: val_loss did not improve from 0.55652
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3465 - val_loss: 0.5630
# Epoch 39/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3401
# Epoch 39: val_loss improved from 0.55652 to 0.55625, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3405 - val_loss: 0.5563
# Epoch 40/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3381
# Epoch 40: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3366 - val_loss: 0.5585
# Epoch 41/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3339
# Epoch 41: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3327 - val_loss: 0.5588
# Epoch 42/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3314
# Epoch 42: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3299 - val_loss: 0.5599
# Epoch 43/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3236
# Epoch 43: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3276 - val_loss: 0.5622
# Epoch 44/50
# 26/30 [=========================>....] - ETA: 0s - loss: 0.3244
# Epoch 44: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3239 - val_loss: 0.5635
# Epoch 45/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3270
# Epoch 45: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3245 - val_loss: 0.5578
# Epoch 46/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3185
# Epoch 46: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3198 - val_loss: 0.5616
# Epoch 47/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3147
# Epoch 47: val_loss did not improve from 0.55625
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3151 - val_loss: 0.5592
# Epoch 48/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3138
# Epoch 48: val_loss improved from 0.55625 to 0.55559, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\bestModel-fold4.hdf5
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3130 - val_loss: 0.5556
# Epoch 49/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3066
# Epoch 49: val_loss did not improve from 0.55559
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3078 - val_loss: 0.5584
# Epoch 50/50
# 25/30 [========================>.....] - ETA: 0s - loss: 0.3015
# Epoch 50: val_loss did not improve from 0.55559
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3034 - val_loss: 0.5587

# %% [markdown]
# ## k-fold Training evaluation

# %%
evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

evaluations_df_grouped
# Out:
#             Accuracy  Precision       AUC  Sensitivity  Specificity       MCC
# Train_Test
# Test        0.759451   0.764704  0.832392     0.750631     0.768299  0.519218
# Train       0.892733   0.902258  0.931971     0.880135     0.905329  0.785856

# %%
evaluations_df[evaluations_df["Train_Test"] == "Test"]
# Out:
#    Fold Train_Test  Accuracy  Precision  \
# 1     0       Test  0.767296   0.778261
# 3     1       Test  0.740042   0.731707
# 5     2       Test  0.714286   0.717949
# 7     3       Test  0.794118   0.799145
# 9     4       Test  0.781513   0.796460
#
#                                                  TPR  \
# 1  [0.0, 0.0041841004184100415, 0.075313807531380...
# 3  [0.0, 0.004201680672268907, 0.0504201680672268...
# 5  [0.0, 0.0, 0.037815126050420166, 0.03781512605...
# 7  [0.0, 0.004201680672268907, 0.0420168067226890...
# 9  [0.0, 0.004201680672268907, 0.0588235294117647...
#
#                                                  FPR  \
# 1  [0.0, 0.0, 0.0, 0.004201680672268907, 0.004201...
# 3  [0.0, 0.0, 0.0, 0.0041841004184100415, 0.00418...
# 5  [0.0, 0.004201680672268907, 0.0042016806722689...
# 7  [0.0, 0.0, 0.0, 0.004201680672268907, 0.004201...
# 9  [0.0, 0.0, 0.0, 0.004201680672268907, 0.004201...
#
#                                   TPR_FPR_Thresholds       AUC  Sensitivity  \
# 1  [1.8303012, 0.83030117, 0.8267717, 0.8260058, ...  0.842797     0.748954
# 3  [1.8155707, 0.8155707, 0.81464505, 0.81464154,...  0.819196     0.756303
# 5  [1.7489326, 0.7489326, 0.7489065, 0.7489033, 0...  0.788821     0.705882
# 7  [1.7979696, 0.7979695, 0.79654115, 0.79643345,...  0.847151     0.785714
# 9  [1.9090337, 0.90903366, 0.9078441, 0.9077635, ...  0.863993     0.756303
#
#    Specificity       MCC
# 1     0.785714  0.535007
# 3     0.723849  0.480388
# 5     0.722689  0.428632
# 7     0.802521  0.588318
# 9     0.806723  0.563742

# %% [markdown]
# # Independent data

# %%
train_features = features
train_labels = labels

# %%
##################################################################################
##### read independent data file
##################################################################################
indpe_file_path = os.path.join(input_data_folder, independent_data_file)
indpe_data = pd.read_csv(indpe_file_path, sep='\t', header=None)
indpe_data.columns = ['Sequence', 'name', 'id', 'flag', 'label_original', 'type']
indpe_data.head()
    
##################################################################################
##### Create OHE of sequence
##################################################################################
indpe_data['OHE_Sequence'] = pd.Series([one_hot_encode_nt(val, all_char_dict) 
                                        for val in indpe_data["Sequence"]])

##################################################################################
##### Fix the labels
##################################################################################
indpe_data['label'] = pd.Series([1 if val == 1 else 0 
                                 for val in indpe_data["label_original"]])

##################################################################################
##### Extract features and labels, create folds
##################################################################################

indpe_features = np.array(list(indpe_data['OHE_Sequence']))
indpe_labels = np.array(list(indpe_data['label']))
indpe_labels = indpe_labels.reshape((indpe_labels.shape[0], 1))

input_seq_shape = indpe_features[0].shape

# %% [markdown]
# ## Using k-fold Models

# %% [markdown]
# ### Performance of each k-fold model

# %%
## create the evaluation data structure for all iterations
evaluations = {
    "Fold" : [],
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

##################################################################################
##### Prediction and metrics for Independent dataset
##################################################################################

for i in range(n_fold):
    
    current_model_path = os.path.join(modelPath, "bestModel-fold{}.hdf5".format(i))
    model = tf.keras.models.load_model(current_model_path)

    y_pred = model.predict(indpe_features)
    label_pred = pred2label(y_pred)

    # Compute precision, recall, sensitivity, specifity, mcc
    acc = accuracy_score(indpe_labels, label_pred)
    prec = precision_score(indpe_labels,label_pred)
    mcc = matthews_corrcoef(indpe_labels, label_pred)

    conf = confusion_matrix(indpe_labels, label_pred)
    tn, fp, fn, tp = conf.ravel()
    sens = tp/(tp+fn)
    spec = tn/(tn+fp)
    
    fpr, tpr, thresholds = roc_curve(indpe_labels, y_pred)
    auc = roc_auc_score(indpe_labels, y_pred)

    evaluations["Fold"].append(i)
    evaluations["Train_Test"].append("Independent")
    evaluations["Accuracy"].append(acc)
    evaluations["Precision"].append(prec)
    evaluations["TPR"].append(tpr)
    evaluations["FPR"].append(fpr)
    evaluations["TPR_FPR_Thresholds"].append(thresholds)
    evaluations["AUC"].append(auc)
    evaluations["Sensitivity"].append(sens)
    evaluations["Specificity"].append(spec)
    evaluations["MCC"].append(mcc)

##################################################################################

evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

evaluations_df_grouped
# Out:
#              Accuracy  Precision       AUC  Sensitivity  Specificity       MCC
# Train_Test
# Independent  0.628408   0.243447  0.658152     0.590148     0.636008  0.171553

# %%
evaluations_df
# Out:
#    Fold   Train_Test  Accuracy  Precision  \
# 0     0  Independent  0.635102   0.253036
# 1     1  Independent  0.617143   0.248106
# 2     2  Independent  0.625306   0.238776
# 3     3  Independent  0.635102   0.241525
# 4     4  Independent  0.629388   0.235789
#
#                                                  TPR  \
# 0  [0.0, 0.0, 0.009852216748768473, 0.00985221674...
# 1  [0.0, 0.0, 0.0049261083743842365, 0.0049261083...
# 2  [0.0, 0.0049261083743842365, 0.009852216748768...
# 3  [0.0, 0.0049261083743842365, 0.004926108374384...
# 4  [0.0, 0.0049261083743842365, 0.004926108374384...
#
#                                                  FPR  \
# 0  [0.0, 0.0009784735812133072, 0.000978473581213...
# 1  [0.0, 0.0009784735812133072, 0.000978473581213...
# 2  [0.0, 0.0, 0.0, 0.004892367906066536, 0.004892...
# 3  [0.0, 0.0, 0.003913894324853229, 0.00391389432...
# 4  [0.0, 0.0, 0.0029354207436399216, 0.0029354207...
#
#                                   TPR_FPR_Thresholds       AUC  Sensitivity  \
# 0  [1.830446, 0.83044606, 0.8303743, 0.83005667, ...  0.664220     0.615764
# 1  [1.8155556, 0.8155555, 0.81550664, 0.8154487, ...  0.671753     0.645320
# 2  [1.7489367, 0.74893665, 0.748936, 0.74893045, ...  0.646188     0.576355
# 3  [1.7981067, 0.7981066, 0.79802597, 0.79801047,...  0.654531     0.561576
# 4  [1.909081, 0.90908104, 0.9089147, 0.908883, 0....  0.654069     0.551724
#
#    Specificity       MCC
# 0     0.638943  0.193060
# 1     0.611546  0.192862
# 2     0.635029  0.160437
# 3     0.649706  0.161424
# 4     0.644814  0.149983

# %% [markdown]
# ### Mean score with k-fold models

# %%
## create the evaluation data structure for all iterations
evaluations = {
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

##################################################################################
##### Prediction and metrics for Independent dataset
##################################################################################

total_pred = np.zeros(indpe_labels.shape)
all_preds = []

for i in range(n_fold):
    
    current_model_path = os.path.join(modelPath, "bestModel-fold{}.hdf5".format(i))
    model = tf.keras.models.load_model(current_model_path)

    y_pred = model.predict(indpe_features)
    total_pred += y_pred
    all_preds.append(y_pred)
    
total_pred = total_pred / n_fold
label_pred = pred2label(total_pred)

# Compute precision, recall, sensitivity, specifity, mcc
acc = accuracy_score(indpe_labels, label_pred)
prec = precision_score(indpe_labels,label_pred)
mcc = matthews_corrcoef(indpe_labels, label_pred)

conf = confusion_matrix(indpe_labels, label_pred)
tn, fp, fn, tp = conf.ravel()
sens = tp/(tp+fn)
spec = tn/(tn+fp)

fpr, tpr, thresholds = roc_curve(indpe_labels, total_pred)
auc = roc_auc_score(indpe_labels, total_pred)

evaluations["Train_Test"].append("Independent")
evaluations["Accuracy"].append(acc)
evaluations["Precision"].append(prec)
evaluations["TPR"].append(tpr)
evaluations["FPR"].append(fpr)
evaluations["TPR_FPR_Thresholds"].append(thresholds)
evaluations["AUC"].append(auc)
evaluations["Sensitivity"].append(sens)
evaluations["Specificity"].append(spec)
evaluations["MCC"].append(mcc)

##################################################################################

evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

evaluations_df_grouped
# Out:
#              Accuracy  Precision       AUC  Sensitivity  Specificity       MCC
# Train_Test
# Independent  0.629388   0.245436  0.669469     0.596059     0.636008  0.175957

# %% [markdown]
# ### Voting score with k-fold models

# %%
## create the evaluation data structure for all iterations
evaluations = {
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

##################################################################################
##### Prediction and metrics for Independent dataset
##################################################################################

total_pred = np.zeros(indpe_labels.shape)
all_preds = []

for i in range(n_fold):
    
    current_model_path = os.path.join(modelPath, "bestModel-fold{}.hdf5".format(i))
    model = tf.keras.models.load_model(current_model_path)

    y_pred = model.predict(indpe_features)
    vote_pred = pred2label(y_pred)
    total_pred += vote_pred
    all_preds.append(vote_pred)
    
total_pred = total_pred / n_fold
label_pred = pred2label(total_pred)

# Compute precision, recall, sensitivity, specifity, mcc
acc = accuracy_score(indpe_labels, label_pred)
prec = precision_score(indpe_labels,label_pred)

mcc = matthews_corrcoef(indpe_labels, label_pred)

conf = confusion_matrix(indpe_labels, label_pred)
tn, fp, fn, tp = conf.ravel()
sens = tp/(tp+fn)
spec = tn/(tn+fp)

fpr, tpr, thresholds = roc_curve(indpe_labels, total_pred)
auc = roc_auc_score(indpe_labels, total_pred)

evaluations["Train_Test"].append("Independent")
evaluations["Accuracy"].append(acc)
evaluations["Precision"].append(prec)
evaluations["TPR"].append(tpr)
evaluations["FPR"].append(fpr)
evaluations["TPR_FPR_Thresholds"].append(thresholds)
evaluations["AUC"].append(auc)
evaluations["Sensitivity"].append(sens)
evaluations["Specificity"].append(spec)
evaluations["MCC"].append(mcc)

##################################################################################

evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

evaluations_df_grouped
# Out:
#              Accuracy  Precision       AUC  Sensitivity  Specificity       MCC
# Train_Test
# Independent  0.635918   0.245283  0.654977     0.576355      0.64775  0.170889

# %% [markdown]
# ## Using New Model
#
# Train model on full data from training. Predict and evaluate on Independent data.

# %%
model = DLNN_CORENup(input_seq_shape = input_seq_shape)
    
## Define the model callbacks for early stopping and saving the model. Then train model
current_model_path = os.path.join(modelPath, "_fullModel.hdf5")
modelCallbacks = [
    tf.keras.callbacks.ModelCheckpoint(current_model_path,
                                       monitor = 'val_loss', verbose = 1, save_best_only = True, 
                                       save_weights_only = False, mode = 'auto', save_freq = 'epoch'),
]

# adding random shuffling of the dataset for training purpose
index_arr = np.arange(train_features.shape[0])
index_arr = np.random.permutation(index_arr)

model.fit(x = train_features[index_arr], y = train_labels[index_arr], batch_size = batch_size, epochs = epochs, verbose = 1, 
          callbacks = modelCallbacks, validation_data = (indpe_features, indpe_labels))
# model.fit(x = train_features[index_arr], y = train_labels[index_arr], batch_size = batch_size, epochs = epochs, verbose = 1, 
#           callbacks = modelCallbacks, validation_split = 0.2)

model = tf.keras.models.load_model(current_model_path)
# Out:
# Epoch 1/50
# 38/38 [==============================] - ETA: 0s - loss: 0.9203
# Epoch 1: val_loss improved from inf to 0.83806, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\_fullModel.hdf5
# 38/38 [==============================] - 3s 27ms/step - loss: 0.9203 - val_loss: 0.8381
# Epoch 2/50
# 36/38 [===========================>..] - ETA: 0s - loss: 0.7603
# Epoch 2: val_loss improved from 0.83806 to 0.82565, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\_fullModel.hdf5
# 38/38 [==============================] - 0s 13ms/step - loss: 0.7577 - val_loss: 0.8257
# Epoch 3/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.6864
# Epoch 3: val_loss improved from 0.82565 to 0.71941, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\_fullModel.hdf5
# 38/38 [==============================] - 1s 13ms/step - loss: 0.6865 - val_loss: 0.7194
# Epoch 4/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.6420
# Epoch 4: val_loss improved from 0.71941 to 0.71235, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\_fullModel.hdf5
# 38/38 [==============================] - 1s 13ms/step - loss: 0.6424 - val_loss: 0.7124
# Epoch 5/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.6147
# Epoch 5: val_loss did not improve from 0.71235
# 38/38 [==============================] - 0s 12ms/step - loss: 0.6141 - val_loss: 0.8396
# Epoch 6/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5899
# Epoch 6: val_loss did not improve from 0.71235
# 38/38 [==============================] - 0s 12ms/step - loss: 0.5901 - val_loss: 0.7256
# Epoch 7/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5664
# Epoch 7: val_loss improved from 0.71235 to 0.69940, saving model to Results\NT_Site_PredNTS_Classification_DLNN_CORENup_v3\5fold\models\_fullModel.hdf5
# 38/38 [==============================] - 0s 13ms/step - loss: 0.5668 - val_loss: 0.6994
# Epoch 8/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5536
# Epoch 8: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 11ms/step - loss: 0.5537 - val_loss: 0.7614
# Epoch 9/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 9: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.5460 - val_loss: 0.7379
# Epoch 10/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5287
# Epoch 10: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.5297 - val_loss: 0.8433
# Epoch 11/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5255
# Epoch 11: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.5258 - val_loss: 0.7631
# Epoch 12/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.5101
# Epoch 12: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.5096 - val_loss: 0.7611
# Epoch 13/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4990
# Epoch 13: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4991 - val_loss: 0.7569
# Epoch 14/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4939
# Epoch 14: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4953 - val_loss: 0.7367
# Epoch 15/50
# 36/38 [===========================>..] - ETA: 0s - loss: 0.4796
# Epoch 15: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4789 - val_loss: 0.7816
# Epoch 16/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4649
# Epoch 16: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 11ms/step - loss: 0.4654 - val_loss: 0.7930
# Epoch 17/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4531
# Epoch 17: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4535 - val_loss: 0.7617
# Epoch 18/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4439
# Epoch 18: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 11ms/step - loss: 0.4438 - val_loss: 0.7259
# Epoch 19/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4403
# Epoch 19: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4400 - val_loss: 0.7200
# Epoch 20/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4299
# Epoch 20: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4304 - val_loss: 0.7671
# Epoch 21/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4152
# Epoch 21: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4156 - val_loss: 0.7641
# Epoch 22/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4057
# Epoch 22: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4065 - val_loss: 0.7864
# Epoch 23/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.4020
# Epoch 23: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.4017 - val_loss: 0.7907
# Epoch 24/50
# 33/38 [=========================>....] - ETA: 0s - loss: 0.3949
# Epoch 24: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 11ms/step - loss: 0.3957 - val_loss: 0.7748
# Epoch 25/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3874
# Epoch 25: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3877 - val_loss: 0.8282
# Epoch 26/50
# 36/38 [===========================>..] - ETA: 0s - loss: 0.3782
# Epoch 26: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3786 - val_loss: 0.7846
# Epoch 27/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3692
# Epoch 27: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3701 - val_loss: 0.8766
# Epoch 28/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3652
# Epoch 28: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3651 - val_loss: 0.7772
# Epoch 29/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3561
# Epoch 29: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3559 - val_loss: 0.7945
# Epoch 30/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3477
# Epoch 30: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 11ms/step - loss: 0.3479 - val_loss: 0.8000
# Epoch 31/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3459
# Epoch 31: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3461 - val_loss: 0.7691
# Epoch 32/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3512
# Epoch 32: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3511 - val_loss: 0.7587
# Epoch 33/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3401
# Epoch 33: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3400 - val_loss: 0.8304
# Epoch 34/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3363
# Epoch 34: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3358 - val_loss: 0.7775
# Epoch 35/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3289
# Epoch 35: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3287 - val_loss: 0.8320
# Epoch 36/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3259
# Epoch 36: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3261 - val_loss: 0.7796
# Epoch 37/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3241
# Epoch 37: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3241 - val_loss: 0.8814
# Epoch 38/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3187
# Epoch 38: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3188 - val_loss: 0.8251
# Epoch 39/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3139
# Epoch 39: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3141 - val_loss: 0.8336
# Epoch 40/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3124
# Epoch 40: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3123 - val_loss: 0.8437
# Epoch 41/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3107
# Epoch 41: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3104 - val_loss: 0.8190
# Epoch 42/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3066
# Epoch 42: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3071 - val_loss: 0.8539
# Epoch 43/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3014
# Epoch 43: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3016 - val_loss: 0.8753
# Epoch 44/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.3010
# Epoch 44: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.3011 - val_loss: 0.8186
# Epoch 45/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.2995
# Epoch 45: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.2991 - val_loss: 0.8696
# Epoch 46/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2971
# Epoch 46: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.2971 - val_loss: 0.7909
# Epoch 47/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.2939
# Epoch 47: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.2940 - val_loss: 0.8825
# Epoch 48/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.2903
# Epoch 48: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.2899 - val_loss: 0.9132
# Epoch 49/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.2927
# Epoch 49: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.2931 - val_loss: 0.8643
# Epoch 50/50
# 37/38 [============================>.] - ETA: 0s - loss: 0.2865
# Epoch 50: val_loss did not improve from 0.69940
# 38/38 [==============================] - 0s 12ms/step - loss: 0.2861 - val_loss: 0.8228

# %%
## create the evaluation data structure for all iterations
evaluations = {
    "Train_Test" : [],
    "Accuracy" : [],
    "Precision": [],
    "TPR": [],
    "FPR": [],
    "TPR_FPR_Thresholds": [],
    "AUC": [],
    "Sensitivity": [],
    "Specificity": [],
    "MCC":[]
}

##################################################################################
##### Prediction and metrics for Independent dataset
##################################################################################

y_pred = model.predict(indpe_features)
label_pred = pred2label(y_pred)

# Compute precision, recall, sensitivity, specifity, mcc
acc = accuracy_score(indpe_labels, label_pred)
prec = precision_score(indpe_labels,label_pred)
mcc = matthews_corrcoef(indpe_labels, label_pred)

conf = confusion_matrix(indpe_labels, label_pred)
tn, fp, fn, tp = conf.ravel()
sens = tp/(tp+fn)
spec = tn/(tn+fp)

fpr, tpr, thresholds = roc_curve(indpe_labels, y_pred)
auc = roc_auc_score(indpe_labels, y_pred)

evaluations["Train_Test"].append("Independent")
evaluations["Accuracy"].append(acc)
evaluations["Precision"].append(prec)
evaluations["TPR"].append(tpr)
evaluations["FPR"].append(fpr)
evaluations["TPR_FPR_Thresholds"].append(thresholds)
evaluations["AUC"].append(auc)
evaluations["Sensitivity"].append(sens)
evaluations["Specificity"].append(spec)
evaluations["MCC"].append(mcc)

##################################################################################

evaluations_df = pd.DataFrame.from_dict(evaluations)

evaluations_df_grouped = evaluations_df.groupby(["Train_Test"]).mean().filter(['Accuracy', 
                                                                               'Precision', 
                                                                               'AUC', 
                                                                               'Sensitivity', 
                                                                               'Specificity', 
                                                                               'MCC'])

evaluations_df_grouped
# Out:
#              Accuracy  Precision       AUC  Sensitivity  Specificity       MCC
# Train_Test
# Independent  0.627755   0.243408  0.653958     0.591133     0.635029  0.171481
